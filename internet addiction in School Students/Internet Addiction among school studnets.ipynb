# %% [markdown]
# original Dataset = https://data.mendeley.com/datasets/xntgmrw6dy/1

# %%
#Importing all lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading DataSet
df=pd.read_csv('C:/Users/manav/Desktop/Stats Project/nternet addiction among School student.csv')
print(df)
# Out:
#      Student ID  Age Name of Website Class  Daily Frequency(Hour)  Gender
# 0          S001   17            Game  Nine                      1    Male
# 1          S002   16            Game   Ten                      5  Female
# 2          S003   15            Game  Nine                      8    Male
# 3          S004   15         Youtube  Nine                      5    Male
# 4          S005   16        Freefire   Ten                      9    Male
# ...         ...  ...             ...   ...                    ...     ...
# 1601      S1602   16            Game   Ten                      5  Female
# 1602      S1603   15            Game  Nine                      8    Male
# 1603      S1604   15         Youtube  Nine                      5    Male
# 1604      S1605   16        Freefire   Ten                      9    Male
# 1605      S1606   16            Game   Ten                      6    Male
#
# [1606 rows x 6 columns]

# %%
# basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606 entries, 0 to 1605
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student ID             1606 non-null   object
#  1   Age                    1606 non-null   int64
#  2   Name of Website        1606 non-null   object
#  3   Class                  1606 non-null   object
#  4   Daily Frequency(Hour)  1606 non-null   int64
#  5   Gender                 1606 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 75.4+ KB
# None

# %%
# Summary of numeric columns
print(df.describe())
# Out:
#                Age  Daily Frequency(Hour)
# count  1606.000000            1606.000000
# mean     14.973225               5.714819
# std       1.135617               2.633760
# min      13.000000               1.000000
# 25%      14.000000               4.000000
# 50%      15.000000               6.000000
# 75%      16.000000               8.000000
# max      17.000000              14.000000

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Student ID               0
# Age                      0
# Name of Website          0
# Class                    0
# Daily Frequency(Hour)    0
# Gender                   0
# dtype: int64

# %%
# Visualizing  numeric columns
plt.figure(figsize=(12, 8))
for i, column in enumerate(df.select_dtypes(include='number').columns):
    plt.subplot(3, 3, i + 1)
    sns.histplot(df[column], kde=True)
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
#are stress, depression, anxiety linked?

correlation_matrix = df[['Age', 'Daily Frequency(Hour)']].corr()

print("Correlation matrix:")
print(correlation_matrix)
# Out:
# Correlation matrix:
#                             Age  Daily Frequency(Hour)
# Age                    1.000000              -0.070881
# Daily Frequency(Hour) -0.070881               1.000000

# %% [markdown]
# The correlation matrix suggests a very weak negative relationship between age and daily frequency (hourly).

# %%
# Visualize correlation matrix
plt.matshow(correlation_matrix)
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation='vertical')
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.colorbar()
plt.show()
